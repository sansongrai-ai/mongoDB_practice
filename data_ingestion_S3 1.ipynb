# %%
spark.conf.set("fs.s3a.access.key", "your_access_key_here")
spark.conf.set("fs.s3a.secret.key", "your_secret_key_here")
 
df = spark.read.csv(
    "s3a://avi1998-bucket/azure/us_states.csv",
    header = True
)
 
df = spark.read.csv("s3a://avi1998-bucket/azure/us_states.csv")
path = "/Volumes/avi_databricks001/default/my_volume/parquet_output"

df.write.format("parquet").mode("overwrite").save(path)
dbutils.notebook.exit(path)
